# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, roc_curve, f1_score, classification_report, auc
from sklearn.cluster import KMeans
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
from imblearn.under_sampling import ClusterCentroids
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
# fix random seed for reproducibility
np.random.seed(7)

# %%
nm_df = pd.read_csv("NetworkMeasuresFeatures.csv")

# %%
nm_df_orig = nm_df.copy()

# %%
# Renaming columns in readable format to understand what each column represents.
nm_df = nm_df_orig.copy()
col_names = ['Actor', 'A_Acc',
             'PartyPlay_InDegree', 'PartyPlay_OutDegree', 'PartyPlay_Degree',
             'PartyPlay_WeightedDegree', 'PartyPlay_WeightedInDegree', 'PartyPlay_WeightedOutDegree',
             'PartyPlay_Eccentricity', 'PartyPlay_ClosenessCentrality', 'PartyPlay_BetweennessCentrality',
             'PartyPlay_Authority', 'PartyPlay_Hub', 'PartyPlay_ModularityClass', 'PartyPlay_Pagerank',
             'PartyPlay_ComponentId', 'PartyPlay_StrConnId', 'PartyPlay_ClusteringCoefficient', 'PartyPlay_Eigenvector',
             'Friendship_InDegree', 'Friendship_OutDegree', 'Friendship_Degree',
             'Friendship_WeightedDegree', 'Friendship_WeightedInDegree', 'Friendship_WeightedOutDegree',
             'Friendship_Eccentricity', 'Friendship_ClosenessCentrality', 'Friendship_BetweennessCentrality',
             'Friendship_Authority', 'Friendship_Hub', 'Friendship_ModularityClass', 'Friendship_Pagerank',
             'Friendship_ComponentId', 'Friendship_StrConnId', 'Friendship_ClusteringCoefficient', 'Friendship_Eigenvector',
             'Trade_InDegree', 'Trade_OutDegree', 'Trade_Degree',
             'Trade_WeightedDegree', 'Trade_WeightedInDegree', 'Trade_WeightedOutDegree',
             'Trade_Eccentricity', 'Trade_ClosenessCentrality', 'Trade_BetweennessCentrality',
             'Trade_Authority', 'Trade_Hub', 'Trade_ModularityClass', 'Trade_Pagerank',
             'Trade_ComponentId', 'Trade_StrConnId', 'Trade_ClusteringCoefficient', 'Trade_Eigenvector',
             'Whisper_InDegree', 'Whisper_OutDegree', 'Whisper_Degree',
             'Whisper_WeightedDegree', 'Whisper_WeightedInDegree', 'Whisper_WeightedOutDegree',
             'Whisper_Eccentricity', 'Whisper_ClosenessCentrality', 'Whisper_BetweennessCentrality',
             'Whisper_Authority', 'Whisper_Hub', 'Whisper_ModularityClass', 'Whisper_Pagerank',
             'Whisper_ComponentId', 'Whisper_StrConnId', 'Whisper_ClusteringCoefficient', 'Whisper_Eigenvector',
             'Mail_InDegree', 'Mail_OutDegree', 'Mail_Degree',
             'Mail_WeightedDegree', 'Mail_WeightedInDegree', 'Mail_WeightedOutDegree',
             'Mail_Eccentricity', 'Mail_ClosenessCentrality', 'Mail_BetweennessCentrality',
             'Mail_Authority', 'Mail_Hub', 'Mail_ModularityClass', 'Mail_Pagerank',
             'Mail_ComponentId', 'Mail_StrConnId', 'Mail_ClusteringCoefficient', 'Mail_Eigenvector',
             'Shop_InDegree', 'Shop_OutDegree', 'Shop_Degree',
             'Shop_WeightedDegree', 'Shop_WeightedInDegree', 'Shop_WeightedOutDegree',
             'Shop_Eccentricity', 'Shop_ClosenessCentrality', 'Shop_BetweennessCentrality',
             'Shop_Authority', 'Shop_Hub', 'Shop_ModularityClass', 'Shop_Pagerank',
             'Shop_ComponentId', 'Shop_StrConnId', 'Shop_ClusteringCoefficient', 'Shop_Eigenvector',
             'Type'
            ]
nm_df.columns = col_names
nm_df_orig.columns = col_names

# %%
# Change Type as Category
nm_df.Type = nm_df.Type.astype('category')

# %%
# Creating a numerical field for Type
nm_df.Type.replace({'Human': 0, 'Bot': 1}, inplace=True)
type_dict = {0 : 'Human', 1: 'Bot'}

# %%
# Creating different datasets based on the Group activity
party_df = nm_df[[
                  'PartyPlay_InDegree', 'PartyPlay_OutDegree', 'PartyPlay_Degree',
                  'PartyPlay_WeightedDegree', 'PartyPlay_WeightedInDegree', 'PartyPlay_WeightedOutDegree',
                  'PartyPlay_Eccentricity', 'PartyPlay_ClosenessCentrality', 'PartyPlay_BetweennessCentrality',
                  'PartyPlay_Authority', 'PartyPlay_Hub', 'PartyPlay_ModularityClass', 'PartyPlay_Pagerank',
                  'PartyPlay_ComponentId', 'PartyPlay_StrConnId', 'PartyPlay_ClusteringCoefficient',
                  'PartyPlay_Eigenvector', 'Type']].copy()
friendship_df = nm_df[['Friendship_InDegree', 'Friendship_OutDegree', 'Friendship_Degree',
                       'Friendship_WeightedDegree', 'Friendship_WeightedInDegree', 'Friendship_WeightedOutDegree',
                       'Friendship_Eccentricity', 'Friendship_ClosenessCentrality', 'Friendship_BetweennessCentrality',
                       'Friendship_Authority', 'Friendship_Hub', 'Friendship_ModularityClass', 'Friendship_Pagerank',
                       'Friendship_ComponentId', 'Friendship_StrConnId', 'Friendship_ClusteringCoefficient', 'Friendship_Eigenvector',
                       'Type']].copy()
trade_df = nm_df[[
    'Trade_InDegree', 'Trade_OutDegree', 'Trade_Degree',
    'Trade_WeightedDegree', 'Trade_WeightedInDegree', 'Trade_WeightedOutDegree',
    'Trade_Eccentricity', 'Trade_ClosenessCentrality', 'Trade_BetweennessCentrality',
    'Trade_Authority', 'Trade_Hub', 'Trade_ModularityClass', 'Trade_Pagerank',
    'Trade_ComponentId', 'Trade_StrConnId', 'Trade_ClusteringCoefficient', 'Trade_Eigenvector',
    'Type']].copy()
shop_df = nm_df[[
             'Shop_InDegree', 'Shop_OutDegree', 'Shop_Degree',
             'Shop_WeightedDegree', 'Shop_WeightedInDegree', 'Shop_WeightedOutDegree',
             'Shop_Eccentricity', 'Shop_ClosenessCentrality', 'Shop_BetweennessCentrality',
             'Shop_Authority', 'Shop_Hub', 'Shop_ModularityClass', 'Shop_Pagerank',
             'Shop_ComponentId', 'Shop_StrConnId', 'Shop_ClusteringCoefficient', 'Shop_Eigenvector',
             'Type']].copy()
whisper_df = nm_df[[
    'Whisper_InDegree', 'Whisper_OutDegree', 'Whisper_Degree',
    'Whisper_WeightedDegree', 'Whisper_WeightedInDegree', 'Whisper_WeightedOutDegree',
    'Whisper_Eccentricity', 'Whisper_ClosenessCentrality', 'Whisper_BetweennessCentrality',
    'Whisper_Authority', 'Whisper_Hub', 'Whisper_ModularityClass', 'Whisper_Pagerank',
    'Whisper_ComponentId', 'Whisper_StrConnId', 'Whisper_ClusteringCoefficient', 'Whisper_Eigenvector',
    'Type' ]].copy()
mail_df = nm_df[[
    'Mail_InDegree', 'Mail_OutDegree', 'Mail_Degree',
    'Mail_WeightedDegree', 'Mail_WeightedInDegree', 'Mail_WeightedOutDegree',
    'Mail_Eccentricity', 'Mail_ClosenessCentrality', 'Mail_BetweennessCentrality',
    'Mail_Authority', 'Mail_Hub', 'Mail_ModularityClass', 'Mail_Pagerank',
    'Mail_ComponentId', 'Mail_StrConnId', 'Mail_ClusteringCoefficient', 'Mail_Eigenvector',
    'Type']].copy()

# %%
# Getting the list of cols that we want to visulaize in pairplot. This will exclude the Actor and A_Acc cols
cols = party_df.columns.tolist()
#cols.remove('Actor'); cols.remove('A_Acc')
print(cols)
# Out:
# ['PartyPlay_InDegree', 'PartyPlay_OutDegree', 'PartyPlay_Degree', 'PartyPlay_WeightedDegree', 'PartyPlay_WeightedInDegree', 'PartyPlay_WeightedOutDegree', 'PartyPlay_Eccentricity', 'PartyPlay_ClosenessCentrality', 'PartyPlay_BetweennessCentrality', 'PartyPlay_Authority', 'PartyPlay_Hub', 'PartyPlay_ModularityClass', 'PartyPlay_Pagerank', 'PartyPlay_ComponentId', 'PartyPlay_StrConnId', 'PartyPlay_ClusteringCoefficient', 'PartyPlay_Eigenvector', 'Type']

# %%
cols_to_zscore = {
    'party_play': ['PartyPlay_BetweennessCentrality', 'PartyPlay_ClosenessCentrality', 
    'PartyPlay_Eigenvector', 'PartyPlay_Eccentricity', 'PartyPlay_Authority', 'PartyPlay_Hub', 'PartyPlay_Pagerank'],
    'friendship': ['Friendship_BetweennessCentrality', 'Friendship_ClosenessCentrality', 
    'Friendship_Eigenvector', 'Friendship_Eccentricity', 'Friendship_Authority', 'Friendship_Hub', 'Friendship_Pagerank'],
    'trade': ['Trade_BetweennessCentrality',  'Trade_ClosenessCentrality',
    'Trade_Eigenvector', 'Trade_Eccentricity', 'Trade_Authority', 'Trade_Hub', 'Trade_Pagerank'],
    'shop': ['Shop_BetweennessCentrality', 'Shop_ClosenessCentrality',
    'Shop_Eigenvector', 'Shop_Eccentricity', 'Shop_Authority', 'Shop_Hub', 'Shop_Pagerank'],
    'mail': ['Mail_BetweennessCentrality', 'Mail_ClosenessCentrality', 
    'Mail_Eigenvector', 'Mail_Eccentricity', 'Mail_Authority', 'Mail_Hub', 'Mail_Pagerank'],
    'whisper': ['Whisper_BetweennessCentrality', 'Whisper_ClosenessCentrality', 
    'Whisper_Eigenvector', 'Whisper_Eccentricity', 'Whisper_Authority', 'Whisper_Hub', 'Whisper_Pagerank']
}

# %%
grp_act_df = {
    'party_play': party_df,
    'friendship': friendship_df,
    'trade': trade_df,
    'shop': shop_df,
    'mail': mail_df,
    'whisper': whisper_df
}

# %%
# For each act_df, apply zscore to the cols listed in cols_to_zscore
for act_name, act_df in grp_act_df.items():
    act_cols_to_zscore = cols_to_zscore.get(act_name)
    act_df[act_cols_to_zscore] = act_df[act_cols_to_zscore].apply(zscore)

# %%
X_cols_to_log_transform = [
    'PartyPlay_InDegree', 'PartyPlay_OutDegree', 'PartyPlay_WeightedInDegree', 'PartyPlay_WeightedOutDegree',
    'Friendship_InDegree', 'Friendship_OutDegree', 'Friendship_WeightedInDegree', 'Friendship_WeightedOutDegree',
    'Trade_InDegree', 'Trade_OutDegree', 'Trade_WeightedInDegree', 'Trade_WeightedOutDegree',
    'Mail_InDegree', 'Mail_OutDegree', 'Mail_WeightedInDegree', 'Mail_WeightedOutDegree',
    'Shop_InDegree', 'Shop_OutDegree', 'Shop_WeightedInDegree', 'Shop_WeightedOutDegree',
    'Whisper_InDegree', 'Whisper_OutDegree', 'Whisper_WeightedInDegree', 'Whisper_WeightedOutDegree',
    'PartyPlay_Degree', 'PartyPlay_WeightedDegree', 'PartyPlay_BetweennessCentrality', 
    'Friendship_Degree', 'Friendship_WeightedDegree', 'Friendship_BetweennessCentrality',
    'Trade_Degree', 'Trade_WeightedDegree', 'Trade_BetweennessCentrality',
    'Shop_Degree', 'Shop_WeightedDegree', 'Shop_BetweennessCentrality',
    'Mail_Degree', 'Mail_WeightedDegree', 'Mail_BetweennessCentrality',
    'Whisper_Degree', 'Whisper_WeightedDegree', 'Whisper_BetweennessCentrality']

# %%
nm_df_zscored = nm_df.copy()

# %%
from scipy import stats as scipy_stats
from scipy.special import boxcox1p
from sklearn.preprocessing import PowerTransformer

nm_df_z_t_1 = nm_df_zscored.copy()
'''
transformer = PowerTransformer(method='yeo-johnson')
X = nm_df_z_t_1[X_cols_to_log_transform]
nm_df_z_t_1[X_cols_to_log_transform] = transformer.fit_transform(X)
'''
for col in X_cols_to_log_transform:
    #print("Transforming %s" % col)
    # The boxcox transformation with value of 0 does log transformation
    nm_df_z_t_1[col] = pd.Series(boxcox1p(nm_df_z_t_1[col].values, 0))
    nm_df_z_t_1[col] = pd.Series(boxcox1p(nm_df_z_t_1[col].values, 0))

# %%
nm_df = nm_df_z_t_1.copy()

# %%
nm_df.corr()
# Out:
#                                      Actor     A_Acc  PartyPlay_InDegree  \
# Actor                             1.000000  0.488634           -0.175530
# A_Acc                             0.488634  1.000000           -0.173875
# PartyPlay_InDegree               -0.175530 -0.173875            1.000000
# PartyPlay_OutDegree              -0.225730 -0.210655            0.827675
# PartyPlay_Degree                 -0.209193 -0.210881            0.904883
# PartyPlay_WeightedDegree         -0.202832 -0.203080            0.887713
# PartyPlay_WeightedInDegree       -0.174194 -0.172943            0.988740
# PartyPlay_WeightedOutDegree      -0.221592 -0.203328            0.815746
# PartyPlay_Eccentricity           -0.185391 -0.219031            0.548015
# PartyPlay_ClosenessCentrality    -0.117984 -0.179034            0.436167
# PartyPlay_BetweennessCentrality  -0.150201 -0.171378            0.899582
# PartyPlay_Authority              -0.135424 -0.081772            0.603609
# PartyPlay_Hub                    -0.138241 -0.083243            0.597182
# PartyPlay_ModularityClass         0.189660  0.142003           -0.106238
# PartyPlay_Pagerank               -0.094150 -0.066327            0.659074
# PartyPlay_ComponentId             0.134160  0.117149           -0.107745
# PartyPlay_StrConnId               0.207083  0.103285           -0.233510
# PartyPlay_ClusteringCoefficient  -0.103554 -0.073165            0.069530
# PartyPlay_Eigenvector            -0.183058 -0.098805            0.521588
# Friendship_InDegree              -0.065215 -0.089377            0.760361
# Friendship_OutDegree             -0.064009 -0.089375            0.759126
# Friendship_Degree                -0.062574 -0.091720            0.746594
# Friendship_WeightedDegree        -0.062997 -0.091773            0.746931
# Friendship_WeightedInDegree      -0.065836 -0.089430            0.760613
# Friendship_WeightedOutDegree     -0.064386 -0.089432            0.759349
# Friendship_Eccentricity          -0.063135 -0.109608            0.614893
# Friendship_ClosenessCentrality   -0.040030 -0.094653            0.563762
# Friendship_BetweennessCentrality -0.076869 -0.094685            0.719396
# Friendship_Authority             -0.051653 -0.044087            0.587805
# Friendship_Hub                   -0.050046 -0.043466            0.587562
# ...                                    ...       ...                 ...
# Mail_WeightedOutDegree           -0.232019 -0.127451            0.357890
# Mail_Eccentricity                -0.155242 -0.090377            0.285180
# Mail_ClosenessCentrality         -0.170359 -0.100345            0.305717
# Mail_BetweennessCentrality       -0.107093 -0.061933            0.193527
# Mail_Authority                   -0.014426 -0.000926            0.012064
# Mail_Hub                         -0.071618 -0.034587            0.110102
# Mail_ModularityClass             -0.000668  0.020978            0.064110
# Mail_Pagerank                    -0.019794 -0.004762            0.021567
# Mail_ComponentId                  0.035099  0.043332            0.005923
# Mail_StrConnId                   -0.021845 -0.045618            0.302977
# Mail_ClusteringCoefficient       -0.055434 -0.010767            0.034018
# Mail_Eigenvector                 -0.010725  0.001041            0.006327
# Shop_InDegree                    -0.341059 -0.175693            0.523189
# Shop_OutDegree                   -0.346984 -0.211224            0.568165
# Shop_Degree                      -0.352862 -0.190734            0.523274
# Shop_WeightedDegree              -0.352367 -0.196369            0.516543
# Shop_WeightedInDegree            -0.343350 -0.186059            0.517022
# Shop_WeightedOutDegree           -0.347562 -0.215000            0.554761
# Shop_Eccentricity                -0.349698 -0.225705            0.475150
# Shop_ClosenessCentrality         -0.331444 -0.219916            0.448669
# Shop_BetweennessCentrality       -0.322334 -0.197066            0.547692
# Shop_Authority                   -0.229130 -0.109484            0.454252
# Shop_Hub                         -0.231482 -0.118582            0.468527
# Shop_ModularityClass             -0.137377 -0.063174            0.231185
# Shop_Pagerank                    -0.233991 -0.117826            0.480043
# Shop_ComponentId                 -0.009794 -0.000522            0.036731
# Shop_StrConnId                   -0.316568 -0.176368            0.397865
# Shop_ClusteringCoefficient       -0.109305 -0.062670            0.121199
# Shop_Eigenvector                 -0.252250 -0.116192            0.404342
# Type                              0.158702  0.293703           -0.279415
#
#                                   PartyPlay_OutDegree  PartyPlay_Degree  \
# Actor                                       -0.225730         -0.209193
# A_Acc                                       -0.210655         -0.210881
# PartyPlay_InDegree                           0.827675          0.904883
# PartyPlay_OutDegree                          1.000000          0.966654
# PartyPlay_Degree                             0.966654          1.000000
# PartyPlay_WeightedDegree                     0.947960          0.985705
# PartyPlay_WeightedInDegree                   0.813277          0.894365
# PartyPlay_WeightedOutDegree                  0.982198          0.953658
# PartyPlay_Eccentricity                       0.774752          0.761789
# PartyPlay_ClosenessCentrality                0.668634          0.661952
# PartyPlay_BetweennessCentrality              0.846054          0.873316
# PartyPlay_Authority                          0.490602          0.514170
# PartyPlay_Hub                                0.491825          0.511407
# PartyPlay_ModularityClass                   -0.132628         -0.082023
# PartyPlay_Pagerank                           0.535002          0.571679
# PartyPlay_ComponentId                       -0.136587         -0.100803
# PartyPlay_StrConnId                         -0.007262         -0.008495
# PartyPlay_ClusteringCoefficient              0.136128          0.148000
# PartyPlay_Eigenvector                        0.431540          0.445255
# Friendship_InDegree                          0.750567          0.756676
# Friendship_OutDegree                         0.749996          0.756188
# Friendship_Degree                            0.744383          0.752815
# Friendship_WeightedDegree                    0.744611          0.752986
# Friendship_WeightedInDegree                  0.750731          0.756758
# Friendship_WeightedOutDegree                 0.750064          0.756209
# Friendship_Eccentricity                      0.649850          0.660380
# Friendship_ClosenessCentrality               0.601335          0.615462
# Friendship_BetweennessCentrality             0.709726          0.709050
# Friendship_Authority                         0.544449          0.542602
# Friendship_Hub                               0.544331          0.542513
# ...                                               ...               ...
# Mail_WeightedOutDegree                       0.346683          0.336763
# Mail_Eccentricity                            0.273947          0.266932
# Mail_ClosenessCentrality                     0.295706          0.287856
# Mail_BetweennessCentrality                   0.179702          0.176025
# Mail_Authority                               0.012160          0.012615
# Mail_Hub                                     0.104696          0.103968
# Mail_ModularityClass                         0.050744          0.048566
# Mail_Pagerank                                0.021025          0.020728
# Mail_ComponentId                            -0.007295         -0.008427
# Mail_StrConnId                               0.293029          0.285520
# Mail_ClusteringCoefficient                   0.028051          0.024392
# Mail_Eigenvector                             0.006781          0.007101
# Shop_InDegree                                0.523754          0.513117
# Shop_OutDegree                               0.589801          0.577341
# Shop_Degree                                  0.539229          0.526532
# Shop_WeightedDegree                          0.532341          0.521017
# Shop_WeightedInDegree                        0.523130          0.512703
# Shop_WeightedOutDegree                       0.573178          0.563255
# Shop_Eccentricity                            0.517172          0.507592
# Shop_ClosenessCentrality                     0.493859          0.485389
# Shop_BetweennessCentrality                   0.568104          0.557433
# Shop_Authority                               0.405528          0.407151
# Shop_Hub                                     0.421710          0.424034
# Shop_ModularityClass                         0.246365          0.241142
# Shop_Pagerank                                0.434036          0.435981
# Shop_ComponentId                             0.033139          0.036646
# Shop_StrConnId                               0.430818          0.420516
# Shop_ClusteringCoefficient                   0.138458          0.134535
# Shop_Eigenvector                             0.366379          0.363995
# Type                                        -0.347976         -0.359481
#
#                                   PartyPlay_WeightedDegree  \
# Actor                                            -0.202832
# A_Acc                                            -0.203080
# PartyPlay_InDegree                                0.887713
# PartyPlay_OutDegree                               0.947960
# PartyPlay_Degree                                  0.985705
# PartyPlay_WeightedDegree                          1.000000
# PartyPlay_WeightedInDegree                        0.893352
# PartyPlay_WeightedOutDegree                       0.962420
# PartyPlay_Eccentricity                            0.764124
# PartyPlay_ClosenessCentrality                     0.672429
# PartyPlay_BetweennessCentrality                   0.855940
# PartyPlay_Authority                               0.491180
# PartyPlay_Hub                                     0.488546
# PartyPlay_ModularityClass                        -0.043497
# PartyPlay_Pagerank                                0.553558
# PartyPlay_ComponentId                            -0.078845
# PartyPlay_StrConnId                               0.017597
# PartyPlay_ClusteringCoefficient                   0.189879
# PartyPlay_Eigenvector                             0.425823
# Friendship_InDegree                               0.742871
# Friendship_OutDegree                              0.742172
# Friendship_Degree                                 0.740826
# Friendship_WeightedDegree                         0.741040
# Friendship_WeightedInDegree                       0.743039
# Friendship_WeightedOutDegree                      0.742240
# Friendship_Eccentricity                           0.651763
# Friendship_ClosenessCentrality                    0.610709
# Friendship_BetweennessCentrality                  0.690974
# Friendship_Authority                              0.525590
# Friendship_Hub                                    0.525460
# ...                                                    ...
# Mail_WeightedOutDegree                            0.329849
# Mail_Eccentricity                                 0.261157
# Mail_ClosenessCentrality                          0.281440
# Mail_BetweennessCentrality                        0.173240
# Mail_Authority                                    0.012459
# Mail_Hub                                          0.102807
# Mail_ModularityClass                              0.050187
# Mail_Pagerank                                     0.020386
# Mail_ComponentId                                 -0.006354
# Mail_StrConnId                                    0.278828
# Mail_ClusteringCoefficient                        0.025836
# Mail_Eigenvector                                  0.007078
# Shop_InDegree                                     0.500381
# Shop_OutDegree                                    0.558449
# Shop_Degree                                       0.512408
# Shop_WeightedDegree                               0.509290
# Shop_WeightedInDegree                             0.501994
# Shop_WeightedOutDegree                            0.548338
# Shop_Eccentricity                                 0.494474
# Shop_ClosenessCentrality                          0.473763
# Shop_BetweennessCentrality                        0.541407
# Shop_Authority                                    0.392862
# Shop_Hub                                          0.409086
# Shop_ModularityClass                              0.236800
# Shop_Pagerank                                     0.421950
# Shop_ComponentId                                  0.040930
# Shop_StrConnId                                    0.411256
# Shop_ClusteringCoefficient                        0.136354
# Shop_Eigenvector                                  0.352198
# Type                                             -0.348657
#
#                                   PartyPlay_WeightedInDegree  \
# Actor                                              -0.174194
# A_Acc                                              -0.172943
# PartyPlay_InDegree                                  0.988740
# PartyPlay_OutDegree                                 0.813277
# PartyPlay_Degree                                    0.894365
# PartyPlay_WeightedDegree                            0.893352
# PartyPlay_WeightedInDegree                          1.000000
# PartyPlay_WeightedOutDegree                         0.811090
# PartyPlay_Eccentricity                              0.547418
# PartyPlay_ClosenessCentrality                       0.440195
# PartyPlay_BetweennessCentrality                     0.891419
# PartyPlay_Authority                                 0.581020
# PartyPlay_Hub                                       0.574518
# PartyPlay_ModularityClass                          -0.084260
# PartyPlay_Pagerank                                  0.640332
# PartyPlay_ComponentId                              -0.096073
# PartyPlay_StrConnId                                -0.223666
# PartyPlay_ClusteringCoefficient                     0.092246
# PartyPlay_Eigenvector                               0.501756
# Friendship_InDegree                                 0.747727
# Friendship_OutDegree                                0.746394
# Friendship_Degree                                   0.735423
# Friendship_WeightedDegree                           0.735820
# Friendship_WeightedInDegree                         0.748084
# Friendship_WeightedOutDegree                        0.746683
# Friendship_Eccentricity                             0.607304
# Friendship_ClosenessCentrality                      0.558992
# Friendship_BetweennessCentrality                    0.706430
# Friendship_Authority                                0.571622
# Friendship_Hub                                      0.571346
# ...                                                      ...
# Mail_WeightedOutDegree                              0.353719
# Mail_Eccentricity                                   0.281767
# Mail_ClosenessCentrality                            0.301939
# Mail_BetweennessCentrality                          0.191758
# Mail_Authority                                      0.012663
# Mail_Hub                                            0.109925
# Mail_ModularityClass                                0.066423
# Mail_Pagerank                                       0.022123
# Mail_ComponentId                                    0.008356
# Mail_StrConnId                                      0.299124
# Mail_ClusteringCoefficient                          0.035796
# Mail_Eigenvector                                    0.007026
# Shop_InDegree                                       0.514394
# Shop_OutDegree                                      0.555809
# Shop_Degree                                         0.514207
# Shop_WeightedDegree                                 0.509404
# Shop_WeightedInDegree                               0.510224
# Shop_WeightedOutDegree                              0.545429
# Shop_Eccentricity                                   0.467966
# Shop_ClosenessCentrality                            0.442680
# Shop_BetweennessCentrality                          0.537599
# Shop_Authority                                      0.440999
# Shop_Hub                                            0.454859
# Shop_ModularityClass                                0.229757
# Shop_Pagerank                                       0.467362
# Shop_ComponentId                                    0.040855
# Shop_StrConnId                                      0.393075
# Shop_ClusteringCoefficient                          0.123392
# Shop_Eigenvector                                    0.393171
# Type                                               -0.271483
#
#                                   PartyPlay_WeightedOutDegree  \
# Actor                                               -0.221592
# A_Acc                                               -0.203328
# PartyPlay_InDegree                                   0.815746
# PartyPlay_OutDegree                                  0.982198
# PartyPlay_Degree                                     0.953658
# PartyPlay_WeightedDegree                             0.962420
# PartyPlay_WeightedInDegree                           0.811090
# PartyPlay_WeightedOutDegree                          1.000000
# PartyPlay_Eccentricity                               0.781672
# PartyPlay_ClosenessCentrality                        0.684023
# PartyPlay_BetweennessCentrality                      0.834315
# PartyPlay_Authority                                  0.471116
# PartyPlay_Hub                                        0.472576
# PartyPlay_ModularityClass                           -0.104421
# PartyPlay_Pagerank                                   0.521013
# PartyPlay_ComponentId                               -0.123384
# PartyPlay_StrConnId                                  0.008063
# PartyPlay_ClusteringCoefficient                      0.184446
# PartyPlay_Eigenvector                                0.416310
# Friendship_InDegree                                  0.738228
# Friendship_OutDegree                                 0.737431
# Friendship_Degree                                    0.733684
# Friendship_WeightedDegree                            0.733984
# Friendship_WeightedInDegree                          0.738512
# Friendship_WeightedOutDegree                         0.737580
# Friendship_Eccentricity                              0.643300
# Friendship_ClosenessCentrality                       0.598309
# Friendship_BetweennessCentrality                     0.693146
# Friendship_Authority                                 0.528739
# Friendship_Hub                                       0.528563
# ...                                                       ...
# Mail_WeightedOutDegree                               0.342218
# Mail_Eccentricity                                    0.270079
# Mail_ClosenessCentrality                             0.291281
# Mail_BetweennessCentrality                           0.178917
# Mail_Authority                                       0.012658
# Mail_Hub                                             0.104842
# Mail_ModularityClass                                 0.052757
# Mail_Pagerank                                        0.021286
# Mail_ComponentId                                    -0.005442
# Mail_StrConnId                                       0.287535
# Mail_ClusteringCoefficient                           0.030775
# Mail_Eigenvector                                     0.007379
# Shop_InDegree                                        0.513957
# Shop_OutDegree                                       0.572767
# Shop_Degree                                          0.527492
# Shop_WeightedDegree                                  0.523344
# Shop_WeightedInDegree                                0.515469
# Shop_WeightedOutDegree                               0.560823
# Shop_Eccentricity                                    0.506480
# Shop_ClosenessCentrality                             0.484650
# Shop_BetweennessCentrality                           0.554253
# Shop_Authority                                       0.394536
# Shop_Hub                                             0.410046
# Shop_ModularityClass                                 0.241670
# Shop_Pagerank                                        0.423079
# Shop_ComponentId                                     0.035919
# Shop_StrConnId                                       0.423157
# Shop_ClusteringCoefficient                           0.142674
# Shop_Eigenvector                                     0.357991
# Type                                                -0.338586
#
#                                   PartyPlay_Eccentricity  \
# Actor                                          -0.185391
# A_Acc                                          -0.219031
# PartyPlay_InDegree                              0.548015
# PartyPlay_OutDegree                             0.774752
# PartyPlay_Degree                                0.761789
# PartyPlay_WeightedDegree                        0.764124
# PartyPlay_WeightedInDegree                      0.547418
# PartyPlay_WeightedOutDegree                     0.781672
# PartyPlay_Eccentricity                          1.000000
# PartyPlay_ClosenessCentrality                   0.975258
# PartyPlay_BetweennessCentrality                 0.662563
# PartyPlay_Authority                             0.221493
# PartyPlay_Hub                                   0.225037
# PartyPlay_ModularityClass                      -0.161802
# PartyPlay_Pagerank                              0.264578
# PartyPlay_ComponentId                          -0.231245
# PartyPlay_StrConnId                             0.185601
# PartyPlay_ClusteringCoefficient                 0.248391
# PartyPlay_Eigenvector                           0.185516
# Friendship_InDegree                             0.467518
# Friendship_OutDegree                            0.468672
# Friendship_Degree                               0.481489
# Friendship_WeightedDegree                       0.481433
# Friendship_WeightedInDegree                     0.467383
# Friendship_WeightedOutDegree                    0.468496
# Friendship_Eccentricity                         0.503046
# Friendship_ClosenessCentrality                  0.488389
# Friendship_BetweennessCentrality                0.425716
# Friendship_Authority                            0.265142
# Friendship_Hub                                  0.265260
# ...                                                  ...
# Mail_WeightedOutDegree                          0.165013
# Mail_Eccentricity                               0.132491
# Mail_ClosenessCentrality                        0.144010
# Mail_BetweennessCentrality                      0.082244
# Mail_Authority                                  0.012446
# Mail_Hub                                        0.051715
# Mail_ModularityClass                           -0.002282
# Mail_Pagerank                                   0.014835
# Mail_ComponentId                               -0.035202
# Mail_StrConnId                                  0.137736
# Mail_ClusteringCoefficient                     -0.002847
# Mail_Eigenvector                                0.010051
# Shop_InDegree                                   0.291834
# Shop_OutDegree                                  0.351069
# Shop_Degree                                     0.312953
# Shop_WeightedDegree                             0.317803
# Shop_WeightedInDegree                           0.303401
# Shop_WeightedOutDegree                          0.351532
# Shop_Eccentricity                               0.349965
# Shop_ClosenessCentrality                        0.347149
# Shop_BetweennessCentrality                      0.342767
# Shop_Authority                                  0.191390
# Shop_Hub                                        0.206438
# Shop_ModularityClass                            0.150445
# Shop_Pagerank                                   0.215497
# Shop_ComponentId                                0.017693
# Shop_StrConnId                                  0.269658
# Shop_ClusteringCoefficient                      0.106178
# Shop_Eigenvector                                0.166641
# Type                                           -0.391885
#
#                                   PartyPlay_ClosenessCentrality    ...     \
# Actor                                                 -0.117984    ...
# A_Acc                                                 -0.179034    ...
# PartyPlay_InDegree                                     0.436167    ...
# PartyPlay_OutDegree                                    0.668634    ...
# PartyPlay_Degree                                       0.661952    ...
# PartyPlay_WeightedDegree                               0.672429    ...
# PartyPlay_WeightedInDegree                             0.440195    ...
# PartyPlay_WeightedOutDegree                            0.684023    ...
# PartyPlay_Eccentricity                                 0.975258    ...
# PartyPlay_ClosenessCentrality                          1.000000    ...
# PartyPlay_BetweennessCentrality                        0.571395    ...
# PartyPlay_Authority                                    0.130426    ...
# PartyPlay_Hub                                          0.134302    ...
# PartyPlay_ModularityClass                             -0.092752    ...
# PartyPlay_Pagerank                                     0.181499    ...
# PartyPlay_ComponentId                                 -0.192494    ...
# PartyPlay_StrConnId                                    0.277117    ...
# PartyPlay_ClusteringCoefficient                        0.258409    ...
# PartyPlay_Eigenvector                                  0.098347    ...
# Friendship_InDegree                                    0.370959    ...
# Friendship_OutDegree                                   0.372356    ...
# Friendship_Degree                                      0.390149    ...
# Friendship_WeightedDegree                              0.389925    ...
# Friendship_WeightedInDegree                            0.370637    ...
# Friendship_WeightedOutDegree                           0.372022    ...
# Friendship_Eccentricity                                0.436080    ...
# Friendship_ClosenessCentrality                         0.434550    ...
# Friendship_BetweennessCentrality                       0.327403    ...
# Friendship_Authority                                   0.175160    ...
# Friendship_Hub                                         0.175404    ...
# ...                                                         ...    ...
# Mail_WeightedOutDegree                                 0.089561    ...
# Mail_Eccentricity                                      0.074043    ...
# Mail_ClosenessCentrality                               0.081413    ...
# Mail_BetweennessCentrality                             0.042786    ...
# Mail_Authority                                         0.008956    ...
# Mail_Hub                                               0.028665    ...
# Mail_ModularityClass                                  -0.016230    ...
# Mail_Pagerank                                          0.009199    ...
# Mail_ComponentId                                      -0.037361    ...
# Mail_StrConnId                                         0.079173    ...
# Mail_ClusteringCoefficient                            -0.015945    ...
# Mail_Eigenvector                                       0.007749    ...
# Shop_InDegree                                          0.180782    ...
# Shop_OutDegree                                         0.233887    ...
# Shop_Degree                                            0.200132    ...
# Shop_WeightedDegree                                    0.207213    ...
# Shop_WeightedInDegree                                  0.193785    ...
# Shop_WeightedOutDegree                                 0.238042    ...
# Shop_Eccentricity                                      0.249906    ...
# Shop_ClosenessCentrality                               0.251381    ...
# Shop_BetweennessCentrality                             0.231123    ...
# Shop_Authority                                         0.105562    ...
# Shop_Hub                                               0.119328    ...
# Shop_ModularityClass                                   0.097317    ...
# Shop_Pagerank                                          0.124753    ...
# Shop_ComponentId                                       0.016723    ...
# Shop_StrConnId                                         0.186490    ...
# Shop_ClusteringCoefficient                             0.078339    ...
# Shop_Eigenvector                                       0.088429    ...
# Type                                                  -0.371373    ...
#
#                                   Shop_BetweennessCentrality  Shop_Authority  \
# Actor                                              -0.322334       -0.229130
# A_Acc                                              -0.197066       -0.109484
# PartyPlay_InDegree                                  0.547692        0.454252
# PartyPlay_OutDegree                                 0.568104        0.405528
# PartyPlay_Degree                                    0.557433        0.407151
# PartyPlay_WeightedDegree                            0.541407        0.392862
# PartyPlay_WeightedInDegree                          0.537599        0.440999
# PartyPlay_WeightedOutDegree                         0.554253        0.394536
# PartyPlay_Eccentricity                              0.342767        0.191390
# PartyPlay_ClosenessCentrality                       0.231123        0.105562
# PartyPlay_BetweennessCentrality                     0.478634        0.336420
# PartyPlay_Authority                                 0.433286        0.653019
# PartyPlay_Hub                                       0.433864        0.654711
# PartyPlay_ModularityClass                          -0.145256       -0.098092
# PartyPlay_Pagerank                                  0.407173        0.607643
# PartyPlay_ComponentId                              -0.103295       -0.062274
# PartyPlay_StrConnId                                -0.137518       -0.098336
# PartyPlay_ClusteringCoefficient                     0.021349       -0.016590
# PartyPlay_Eigenvector                               0.442028        0.697354
# Friendship_InDegree                                 0.466628        0.426345
# Friendship_OutDegree                                0.465908        0.424624
# Friendship_Degree                                   0.455345        0.399987
# Friendship_WeightedDegree                           0.456056        0.401116
# Friendship_WeightedInDegree                         0.467432        0.427668
# Friendship_WeightedOutDegree                        0.466559        0.425817
# Friendship_Eccentricity                             0.368383        0.261292
# Friendship_ClosenessCentrality                      0.323135        0.213737
# Friendship_BetweennessCentrality                    0.448466        0.384424
# Friendship_Authority                                0.382395        0.482049
# Friendship_Hub                                      0.381456        0.480530
# ...                                                      ...             ...
# Mail_WeightedOutDegree                              0.367794        0.375735
# Mail_Eccentricity                                   0.292127        0.322378
# Mail_ClosenessCentrality                            0.310879        0.333024
# Mail_BetweennessCentrality                          0.206248        0.269992
# Mail_Authority                                      0.022499        0.027817
# Mail_Hub                                            0.112518        0.122267
# Mail_ModularityClass                                0.039702        0.042968
# Mail_Pagerank                                       0.033033        0.033698
# Mail_ComponentId                                   -0.017287       -0.008098
# Mail_StrConnId                                      0.244319        0.222625
# Mail_ClusteringCoefficient                          0.058319        0.057193
# Mail_Eigenvector                                    0.016375        0.020707
# Shop_InDegree                                       0.922494        0.716998
# Shop_OutDegree                                      0.958541        0.695273
# Shop_Degree                                         0.931517        0.678067
# Shop_WeightedDegree                                 0.923086        0.646829
# Shop_WeightedInDegree                               0.921026        0.670416
# Shop_WeightedOutDegree                              0.945728        0.657597
# Shop_Eccentricity                                   0.860635        0.477351
# Shop_ClosenessCentrality                            0.830594        0.421400
# Shop_BetweennessCentrality                          1.000000        0.632801
# Shop_Authority                                      0.632801        1.000000
# Shop_Hub                                            0.645360        0.988617
# Shop_ModularityClass                                0.480963        0.258958
# Shop_Pagerank                                       0.687773        0.978681
# Shop_ComponentId                                    0.054715        0.041034
# Shop_StrConnId                                      0.734014        0.448301
# Shop_ClusteringCoefficient                          0.229245        0.101115
# Shop_Eigenvector                                    0.555098        0.952240
# Type                                               -0.168241       -0.082851
#
#                                   Shop_Hub  Shop_ModularityClass  \
# Actor                            -0.231482             -0.137377
# A_Acc                            -0.118582             -0.063174
# PartyPlay_InDegree                0.468527              0.231185
# PartyPlay_OutDegree               0.421710              0.246365
# PartyPlay_Degree                  0.424034              0.241142
# PartyPlay_WeightedDegree          0.409086              0.236800
# PartyPlay_WeightedInDegree        0.454859              0.229757
# PartyPlay_WeightedOutDegree       0.410046              0.241670
# PartyPlay_Eccentricity            0.206438              0.150445
# PartyPlay_ClosenessCentrality     0.119328              0.097317
# PartyPlay_BetweennessCentrality   0.350095              0.209991
# PartyPlay_Authority               0.662110              0.154941
# PartyPlay_Hub                     0.663822              0.154506
# PartyPlay_ModularityClass        -0.097657             -0.083460
# PartyPlay_Pagerank                0.617287              0.139976
# PartyPlay_ComponentId            -0.061874             -0.067523
# PartyPlay_StrConnId              -0.094621             -0.088295
# PartyPlay_ClusteringCoefficient  -0.014964              0.016013
# PartyPlay_Eigenvector             0.706220              0.140649
# Friendship_InDegree               0.439967              0.169739
# Friendship_OutDegree              0.438580              0.169092
# Friendship_Degree                 0.413887              0.165579
# Friendship_WeightedDegree         0.415012              0.165920
# Friendship_WeightedInDegree       0.441285              0.170131
# Friendship_WeightedOutDegree      0.439760              0.169416
# Friendship_Eccentricity           0.274720              0.135506
# Friendship_ClosenessCentrality    0.226657              0.117572
# Friendship_BetweennessCentrality  0.396335              0.172979
# Friendship_Authority              0.491526              0.138339
# Friendship_Hub                    0.490090              0.137980
# ...                                    ...                   ...
# Mail_WeightedOutDegree            0.379138              0.140550
# Mail_Eccentricity                 0.326398              0.096252
# Mail_ClosenessCentrality          0.337178              0.106360
# Mail_BetweennessCentrality        0.272283              0.060368
# Mail_Authority                    0.026358              0.015802
# Mail_Hub                          0.121724              0.045832
# Mail_ModularityClass              0.040835              0.036305
# Mail_Pagerank                     0.032451              0.023168
# Mail_ComponentId                 -0.011150              0.011986
# Mail_StrConnId                    0.225360              0.119031
# Mail_ClusteringCoefficient        0.055046              0.041862
# Mail_Eigenvector                  0.019245              0.013582
# Shop_InDegree                     0.703024              0.557428
# Shop_OutDegree                    0.709712              0.494543
# Shop_Degree                       0.668182              0.586062
# Shop_WeightedDegree               0.639690              0.582665
# Shop_WeightedInDegree             0.660702              0.557753
# Shop_WeightedOutDegree            0.671863              0.500491
# Shop_Eccentricity                 0.492023              0.536473
# Shop_ClosenessCentrality          0.435801              0.547358
# Shop_BetweennessCentrality        0.645360              0.480963
# Shop_Authority                    0.988617              0.258958
# Shop_Hub                          1.000000              0.244327
# Shop_ModularityClass              0.244327              1.000000
# Shop_Pagerank                     0.976778              0.319481
# Shop_ComponentId                  0.038985              0.351218
# Shop_StrConnId                    0.447511              0.608695
# Shop_ClusteringCoefficient        0.096573              0.201821
# Shop_Eigenvector                  0.936851              0.173767
# Type                             -0.105122             -0.017195
#
#                                   Shop_Pagerank  Shop_ComponentId  \
# Actor                                 -0.233991         -0.009794
# A_Acc                                 -0.117826         -0.000522
# PartyPlay_InDegree                     0.480043          0.036731
# PartyPlay_OutDegree                    0.434036          0.033139
# PartyPlay_Degree                       0.435981          0.036646
# PartyPlay_WeightedDegree               0.421950          0.040930
# PartyPlay_WeightedInDegree             0.467362          0.040855
# PartyPlay_WeightedOutDegree            0.423079          0.035919
# PartyPlay_Eccentricity                 0.215497          0.017693
# PartyPlay_ClosenessCentrality          0.124753          0.016723
# PartyPlay_BetweennessCentrality        0.363300          0.029109
# PartyPlay_Authority                    0.647514          0.021636
# PartyPlay_Hub                          0.648817          0.021440
# PartyPlay_ModularityClass             -0.103967          0.008704
# PartyPlay_Pagerank                     0.610921          0.023785
# PartyPlay_ComponentId                 -0.068727          0.003748
# PartyPlay_StrConnId                   -0.107703          0.014835
# PartyPlay_ClusteringCoefficient       -0.012682          0.000111
# PartyPlay_Eigenvector                  0.682848          0.025285
# Friendship_InDegree                    0.445823          0.031392
# Friendship_OutDegree                   0.444430          0.031296
# Friendship_Degree                      0.419814          0.031225
# Friendship_WeightedDegree              0.420922          0.031507
# Friendship_WeightedInDegree            0.447075          0.031730
# Friendship_WeightedOutDegree           0.445631          0.031671
# Friendship_Eccentricity                0.279591          0.023760
# Friendship_ClosenessCentrality         0.231523          0.021834
# Friendship_BetweennessCentrality       0.404441          0.026624
# Friendship_Authority                   0.496317          0.026111
# Friendship_Hub                         0.494863          0.026075
# ...                                         ...               ...
# Mail_WeightedOutDegree                 0.386075          0.008885
# Mail_Eccentricity                      0.331365          0.000397
# Mail_ClosenessCentrality               0.342288          0.002558
# Mail_BetweennessCentrality             0.273809          0.002704
# Mail_Authority                         0.030844         -0.000146
# Mail_Hub                               0.126666          0.002882
# Mail_ModularityClass                   0.047046         -0.000930
# Mail_Pagerank                          0.037309          0.001235
# Mail_ComponentId                      -0.008741          0.002505
# Mail_StrConnId                         0.233520          0.010472
# Mail_ClusteringCoefficient             0.060728         -0.000095
# Mail_Eigenvector                       0.023706         -0.000398
# Shop_InDegree                          0.759932          0.094428
# Shop_OutDegree                         0.749133          0.086581
# Shop_Degree                            0.728995          0.107669
# Shop_WeightedDegree                    0.703349          0.115080
# Shop_WeightedInDegree                  0.721866          0.103870
# Shop_WeightedOutDegree                 0.716667          0.096925
# Shop_Eccentricity                      0.537241          0.078057
# Shop_ClosenessCentrality               0.489441          0.076175
# Shop_BetweennessCentrality             0.687773          0.054715
# Shop_Authority                         0.978681          0.041034
# Shop_Hub                               0.976778          0.038985
# Shop_ModularityClass                   0.319481          0.351218
# Shop_Pagerank                          1.000000          0.071904
# Shop_ComponentId                       0.071904          1.000000
# Shop_StrConnId                         0.499626          0.257019
# Shop_ClusteringCoefficient             0.121524          0.021614
# Shop_Eigenvector                       0.899961          0.039677
# Type                                  -0.095750         -0.002975
#
#                                   Shop_StrConnId  Shop_ClusteringCoefficient  \
# Actor                                  -0.316568                   -0.109305
# A_Acc                                  -0.176368                   -0.062670
# PartyPlay_InDegree                      0.397865                    0.121199
# PartyPlay_OutDegree                     0.430818                    0.138458
# PartyPlay_Degree                        0.420516                    0.134535
# PartyPlay_WeightedDegree                0.411256                    0.136354
# PartyPlay_WeightedInDegree              0.393075                    0.123392
# PartyPlay_WeightedOutDegree             0.423157                    0.142674
# PartyPlay_Eccentricity                  0.269658                    0.106178
# PartyPlay_ClosenessCentrality           0.186490                    0.078339
# PartyPlay_BetweennessCentrality         0.353583                    0.116900
# PartyPlay_Authority                     0.291173                    0.055334
# PartyPlay_Hub                           0.291967                    0.055809
# PartyPlay_ModularityClass              -0.149387                   -0.051185
# PartyPlay_Pagerank                      0.263980                    0.052217
# PartyPlay_ComponentId                  -0.103810                   -0.038029
# PartyPlay_StrConnId                    -0.096991                   -0.041075
# PartyPlay_ClusteringCoefficient         0.048278                    0.062985
# PartyPlay_Eigenvector                   0.310238                    0.061822
# Friendship_InDegree                     0.307475                    0.096084
# Friendship_OutDegree                    0.306599                    0.095193
# Friendship_Degree                       0.300715                    0.096574
# Friendship_WeightedDegree               0.301389                    0.096861
# Friendship_WeightedInDegree             0.308285                    0.096397
# Friendship_WeightedOutDegree            0.307246                    0.095538
# Friendship_Eccentricity                 0.253998                    0.092905
# Friendship_ClosenessCentrality          0.216763                    0.083314
# Friendship_BetweennessCentrality        0.301068                    0.092437
# Friendship_Authority                    0.246628                    0.060333
# Friendship_Hub                          0.245786                    0.059982
# ...                                          ...                         ...
# Mail_WeightedOutDegree                  0.254557                    0.081119
# Mail_Eccentricity                       0.173804                    0.055225
# Mail_ClosenessCentrality                0.192580                    0.060245
# Mail_BetweennessCentrality              0.128374                    0.036121
# Mail_Authority                          0.023535                    0.029187
# Mail_Hub                                0.081441                    0.030032
# Mail_ModularityClass                    0.033398                    0.013431
# Mail_Pagerank                           0.034029                    0.031853
# Mail_ComponentId                        0.004894                   -0.001633
# Mail_StrConnId                          0.177211                    0.051302
# Mail_ClusteringCoefficient              0.056549                    0.022187
# Mail_Eigenvector                        0.019256                    0.028967
# Shop_InDegree                           0.782995                    0.286109
# Shop_OutDegree                          0.787457                    0.268749
# Shop_Degree                             0.838534                    0.304790
# Shop_WeightedDegree                     0.840026                    0.320295
# Shop_WeightedInDegree                   0.793977                    0.309377
# Shop_WeightedOutDegree                  0.795176                    0.292649
# Shop_Eccentricity                       0.879953                    0.313595
# Shop_ClosenessCentrality                0.851333                    0.316555
# Shop_BetweennessCentrality              0.734014                    0.229245
# Shop_Authority                          0.448301                    0.101115
# Shop_Hub                                0.447511                    0.096573
# Shop_ModularityClass                    0.608695                    0.201821
# Shop_Pagerank                           0.499626                    0.121524
# Shop_ComponentId                        0.257019                    0.021614
# Shop_StrConnId                          1.000000                    0.291175
# Shop_ClusteringCoefficient              0.291175                    1.000000
# Shop_Eigenvector                        0.409753                    0.092637
# Type                                   -0.110334                   -0.027859
#
#                                   Shop_Eigenvector      Type
# Actor                                    -0.252250  0.158702
# A_Acc                                    -0.116192  0.293703
# PartyPlay_InDegree                        0.404342 -0.279415
# PartyPlay_OutDegree                       0.366379 -0.347976
# PartyPlay_Degree                          0.363995 -0.359481
# PartyPlay_WeightedDegree                  0.352198 -0.348657
# PartyPlay_WeightedInDegree                0.393171 -0.271483
# PartyPlay_WeightedOutDegree               0.357991 -0.338586
# PartyPlay_Eccentricity                    0.166641 -0.391885
# PartyPlay_ClosenessCentrality             0.088429 -0.371373
# PartyPlay_BetweennessCentrality           0.295821 -0.304930
# PartyPlay_Authority                       0.595334 -0.124993
# PartyPlay_Hub                             0.597979 -0.125378
# PartyPlay_ModularityClass                -0.090325  0.096499
# PartyPlay_Pagerank                        0.555773 -0.141753
# PartyPlay_ComponentId                    -0.054173  0.112367
# PartyPlay_StrConnId                      -0.081521 -0.047287
# PartyPlay_ClusteringCoefficient          -0.009466 -0.056775
# PartyPlay_Eigenvector                     0.673207 -0.106645
# Friendship_InDegree                       0.387633 -0.260279
# Friendship_OutDegree                      0.385866 -0.261097
# Friendship_Degree                         0.362756 -0.268299
# Friendship_WeightedDegree                 0.363989 -0.267759
# Friendship_WeightedInDegree               0.389143 -0.259441
# Friendship_WeightedOutDegree              0.387160 -0.260586
# Friendship_Eccentricity                   0.235156 -0.280021
# Friendship_ClosenessCentrality            0.188895 -0.271494
# Friendship_BetweennessCentrality          0.346328 -0.228561
# Friendship_Authority                      0.444200 -0.147306
# Friendship_Hub                            0.442507 -0.147894
# ...                                            ...       ...
# Mail_WeightedOutDegree                    0.362756 -0.071910
# Mail_Eccentricity                         0.311140 -0.068473
# Mail_ClosenessCentrality                  0.320700 -0.073880
# Mail_BetweennessCentrality                0.273270 -0.034450
# Mail_Authority                            0.027814  0.021494
# Mail_Hub                                  0.120072 -0.004858
# Mail_ModularityClass                      0.035381  0.045979
# Mail_Pagerank                             0.032834  0.017467
# Mail_ComponentId                         -0.009641  0.059512
# Mail_StrConnId                            0.194893 -0.050889
# Mail_ClusteringCoefficient                0.054743  0.021137
# Mail_Eigenvector                          0.020733  0.022646
# Shop_InDegree                             0.641662 -0.095217
# Shop_OutDegree                            0.621140 -0.180840
# Shop_Degree                               0.603707 -0.113656
# Shop_WeightedDegree                       0.574587 -0.122957
# Shop_WeightedInDegree                     0.597895 -0.110968
# Shop_WeightedOutDegree                    0.585872 -0.182480
# Shop_Eccentricity                         0.418385 -0.186084
# Shop_ClosenessCentrality                  0.354656 -0.183719
# Shop_BetweennessCentrality                0.555098 -0.168241
# Shop_Authority                            0.952240 -0.082851
# Shop_Hub                                  0.936851 -0.105122
# Shop_ModularityClass                      0.173767 -0.017195
# Shop_Pagerank                             0.899961 -0.095750
# Shop_ComponentId                          0.039677 -0.002975
# Shop_StrConnId                            0.409753 -0.110334
# Shop_ClusteringCoefficient                0.092637 -0.027859
# Shop_Eigenvector                          1.000000 -0.072602
# Type                                     -0.072602  1.000000
#
# [105 rows x 105 columns]

# %%
X_cols = ['PartyPlay_InDegree', 'PartyPlay_OutDegree', 'PartyPlay_WeightedInDegree', 'PartyPlay_WeightedOutDegree',
    'PartyPlay_ClusteringCoefficient',
    'Friendship_InDegree', 'Friendship_OutDegree', 'Friendship_WeightedInDegree', 'Friendship_WeightedOutDegree',
    'Friendship_ClusteringCoefficient',
    'Trade_InDegree', 'Trade_OutDegree', 'Trade_WeightedInDegree', 'Trade_WeightedOutDegree',
    'Trade_ClusteringCoefficient',
    'Mail_InDegree', 'Mail_OutDegree', 'Mail_WeightedInDegree', 'Mail_WeightedOutDegree',
    'Mail_ClusteringCoefficient',
    'Shop_InDegree', 'Shop_OutDegree', 'Shop_WeightedInDegree', 'Shop_WeightedOutDegree',
    'Shop_ClusteringCoefficient', 
    'Whisper_InDegree', 'Whisper_OutDegree', 'Whisper_WeightedInDegree', 'Whisper_WeightedOutDegree',
    'Whisper_ClusteringCoefficient',
    'PartyPlay_Degree', 'PartyPlay_WeightedDegree', 'PartyPlay_BetweennessCentrality', 'PartyPlay_ClosenessCentrality', 
    'PartyPlay_Eigenvector', 'PartyPlay_Eccentricity', 'PartyPlay_Authority', 'PartyPlay_Hub', 'PartyPlay_Pagerank',
    'Friendship_Degree', 'Friendship_WeightedDegree', 'Friendship_BetweennessCentrality', 'Friendship_ClosenessCentrality', 
    'Friendship_Eigenvector', 'Friendship_Eccentricity', 'Friendship_Authority', 'Friendship_Hub', 'Friendship_Pagerank',
    'Trade_Degree', 'Trade_WeightedDegree', 'Trade_BetweennessCentrality',  'Trade_ClosenessCentrality',
    'Trade_Eigenvector', 'Trade_Eccentricity', 'Trade_Authority', 'Trade_Hub', 'Trade_Pagerank',
    'Shop_Degree', 'Shop_WeightedDegree', 'Shop_BetweennessCentrality', 'Shop_ClosenessCentrality',
    'Shop_Eigenvector', 'Shop_Eccentricity', 'Shop_Authority', 'Shop_Hub', 'Shop_Pagerank',
    'Mail_Degree', 'Mail_WeightedDegree', 'Mail_BetweennessCentrality', 'Mail_ClosenessCentrality', 
    'Mail_Eigenvector', 'Mail_Eccentricity', 'Mail_Authority', 'Mail_Hub', 'Mail_Pagerank']
#X_cols = list(col_names)
#X_cols.remove('A_Acc');
#X_cols.remove('Type')
#print(X_cols) 
#X_cols = ['PartyPlay_InDegree', 'PartyPlay_OutDegree', 'PartyPlay_WeightedInDegree', 'PartyPlay_WeightedOutDegree',
#    'PartyPlay_ClusteringCoefficient', 'PartyPlay_Degree', 'PartyPlay_WeightedDegree', 'PartyPlay_BetweennessCentrality', 'PartyPlay_ClosenessCentrality', 
#    'PartyPlay_Eigenvector', 'PartyPlay_Eccentricity', 'PartyPlay_Authority', 'PartyPlay_Hub', 'PartyPlay_Pagerank']
y_col = ['Type']
X = nm_df[X_cols]
y = nm_df[y_col]

# %%
# We will cluster each of the cols in cols_to_zscore and assign a cluster number to each, replacing its original value
# by its cluster number. This is to make the model better as it will then the model will not have to get build
# on scatter values, but on values which represents its cluster, which are very less in number. We do this for
# every such feature in cols_to_zscore on not just on the all the features taken as whole.
k_means_cluster_num = 3

# %%
# For each feature, get predicted cluster. Put the resultant cluster value of the feature against new nm_df dataframe
nm_df_z_t_c = nm_df_z_t_1.copy()
for act_name, act_df in grp_act_df.items():
    act_cols = cols_to_zscore.get(act_name)
    for act_col in act_cols:
        tmp_df = pd.DataFrame({act_col: act_df[act_col].copy()})
        clusters = KMeans(n_clusters=k_means_cluster_num, random_state=7, n_init=10)
        clusters.fit(tmp_df)
        predicted_clusters_array = clusters.predict(tmp_df)
        nm_df_z_t_c[act_col] = predicted_clusters_array

# %%
nm_df = nm_df_z_t_c.copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# %%
model = Sequential()
model.add(Dense(75, input_dim=75, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(300, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=30, batch_size=50)
# Out:
# Epoch 1/30
# 34817/34817 [==============================] - 4s 103us/step - loss: 0.2983 - acc: 0.8976
# Epoch 2/30
# 34817/34817 [==============================] - 2s 70us/step - loss: 0.2782 - acc: 0.9065
# Epoch 3/30
# 34817/34817 [==============================] - 2s 69us/step - loss: 0.2728 - acc: 0.9104
# Epoch 4/30
# 34817/34817 [==============================] - 2s 69us/step - loss: 0.2690 - acc: 0.9119
# Epoch 5/30
# 34817/34817 [==============================] - 2s 70us/step - loss: 0.2677 - acc: 0.9120
# Epoch 6/30
# 34817/34817 [==============================] - 3s 74us/step - loss: 0.2654 - acc: 0.9130
# Epoch 7/30
# 34817/34817 [==============================] - 3s 80us/step - loss: 0.2623 - acc: 0.9144
# Epoch 8/30
# 34817/34817 [==============================] - 3s 73us/step - loss: 0.2609 - acc: 0.9148
# Epoch 9/30
# 34817/34817 [==============================] - 3s 73us/step - loss: 0.2595 - acc: 0.9148
# Epoch 10/30
# 34817/34817 [==============================] - 3s 79us/step - loss: 0.2589 - acc: 0.9151
# Epoch 11/30
# 34817/34817 [==============================] - 3s 88us/step - loss: 0.2567 - acc: 0.9164
# Epoch 12/30
# 34817/34817 [==============================] - 3s 78us/step - loss: 0.2554 - acc: 0.9165
# Epoch 13/30
# 34817/34817 [==============================] - 3s 76us/step - loss: 0.2544 - acc: 0.9173
# Epoch 14/30
# 34817/34817 [==============================] - 3s 78us/step - loss: 0.2523 - acc: 0.9177
# Epoch 15/30
# 34817/34817 [==============================] - 3s 78us/step - loss: 0.2510 - acc: 0.9184
# Epoch 16/30
# 34817/34817 [==============================] - 3s 77us/step - loss: 0.2510 - acc: 0.9191
# Epoch 17/30
# 34817/34817 [==============================] - 3s 80us/step - loss: 0.2485 - acc: 0.9198
# Epoch 18/30
# 34817/34817 [==============================] - 3s 87us/step - loss: 0.2480 - acc: 0.9201
# Epoch 19/30
# 34817/34817 [==============================] - 3s 77us/step - loss: 0.2458 - acc: 0.9204
# Epoch 20/30
# 34817/34817 [==============================] - 3s 77us/step - loss: 0.2462 - acc: 0.9202
# Epoch 21/30
# 34817/34817 [==============================] - 3s 98us/step - loss: 0.2441 - acc: 0.9208
# Epoch 22/30
# 34817/34817 [==============================] - 3s 75us/step - loss: 0.2431 - acc: 0.9216
# Epoch 23/30
# 34817/34817 [==============================] - 3s 75us/step - loss: 0.2422 - acc: 0.9219
# Epoch 24/30
# 34817/34817 [==============================] - 3s 72us/step - loss: 0.2408 - acc: 0.9227
# Epoch 25/30
# 34817/34817 [==============================] - 3s 80us/step - loss: 0.2398 - acc: 0.9231
# Epoch 26/30
# 34817/34817 [==============================] - 4s 114us/step - loss: 0.2391 - acc: 0.9226
# Epoch 27/30
# 34817/34817 [==============================] - 3s 98us/step - loss: 0.2378 - acc: 0.9234
# Epoch 28/30
# 34817/34817 [==============================] - 4s 106us/step - loss: 0.2368 - acc: 0.9237
# Epoch 29/30
# 34817/34817 [==============================] - 4s 104us/step - loss: 0.2354 - acc: 0.9242
# Epoch 30/30
# 34817/34817 [==============================] - 3s 74us/step - loss: 0.2340 - acc: 0.9250

# %%
# evaluate the model
scores = model.evaluate(X_test, y_test)
scores[1]*100
# Out:
# 14922/14922 [==============================] - 2s 104us/step
# 91.66331590779777

# %%
y_predict = model.predict_classes(X_test)
cr = metrics.classification_report(y_test ,y_predict)
print(cr)

cm = metrics.confusion_matrix(y_test,y_predict)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     12672
#            1       0.83      0.56      0.67      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.88      0.77      0.81     14922
# weighted avg       0.91      0.92      0.91     14922
#
# [[12420   252]
#  [  992  1258]]

# %%
fpr, tpr, threshold = roc_curve(y_test, y_predict)
roc_auc = auc(fpr, tpr)
print("AUC %s" % roc_auc)
# Out:
# AUC 0.7696123737373737

# %%
type(X), type(y)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
from sklearn.model_selection import StratifiedKFold
# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=10, shuffle=True)
cvscores = []
for train, test in kfold.split(X, y):
    #print(train)
    #print(test)
    # create model
    model = Sequential()
    model.add(Dense(75, input_dim=75, activation='relu'))
    model.add(Dense(300, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    model.fit(X.iloc[train],
              y.iloc[train], epochs=10, batch_size=100, verbose=0)
    # evaluate the model
    scores = model.evaluate(X.iloc[test], y.iloc[test], verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    y_predict = model.predict_classes(X_test)
    cr = metrics.classification_report(y_test ,y_predict)
    print(cr)
    cm = metrics.confusion_matrix(y_test,y_predict)
    print(cm)
    fpr, tpr, threshold = roc_curve(y_test, y_predict)
    roc_auc = auc(fpr, tpr)
    print("AUC %s" % roc_auc)
# Out:
# acc: 90.91%
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     12672
#            1       0.82      0.60      0.70      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.88      0.79      0.83     14922
# weighted avg       0.92      0.92      0.92     14922
#
# [[12380   292]
#  [  893  1357]]
# AUC 0.7900340909090909
# acc: 91.44%
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     12672
#            1       0.87      0.56      0.68      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.90      0.77      0.82     14922
# weighted avg       0.92      0.92      0.91     14922
#
# [[12475   197]
#  [  981  1269]]
# AUC 0.7742269570707071
# acc: 91.62%
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.95     12672
#            1       0.87      0.56      0.68      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.90      0.77      0.82     14922
# weighted avg       0.92      0.92      0.91     14922
#
# [[12485   187]
#  [  991  1259]]
# AUC 0.7723993055555556
# acc: 91.80%
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     12672
#            1       0.85      0.59      0.70      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.89      0.79      0.83     14922
# weighted avg       0.92      0.92      0.92     14922
#
# [[12433   239]
#  [  920  1330]]
# AUC 0.7861253156565656
# acc: 91.68%
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     12672
#            1       0.88      0.56      0.68      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.90      0.77      0.82     14922
# weighted avg       0.92      0.92      0.91     14922
#
# [[12498   174]
#  [  995  1255]]
# AUC 0.7720233585858587
# acc: 91.58%
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     12672
#            1       0.85      0.59      0.70      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.89      0.79      0.83     14922
# weighted avg       0.92      0.92      0.92     14922
#
# [[12445   227]
#  [  918  1332]]
# AUC 0.7870432449494951
# acc: 91.76%
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     12672
#            1       0.90      0.53      0.66      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.91      0.76      0.81     14922
# weighted avg       0.92      0.92      0.91     14922
#
# [[12538   134]
#  [ 1068  1182]]
# AUC 0.7573794191919191
# acc: 91.11%
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     12672
#            1       0.86      0.57      0.68      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.89      0.78      0.82     14922
# weighted avg       0.92      0.92      0.91     14922
#
# [[12464   208]
#  [  974  1276]]
# AUC 0.7753484848484848
# acc: 91.07%
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     12672
#            1       0.84      0.59      0.69      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.89      0.79      0.82     14922
# weighted avg       0.92      0.92      0.92     14922
#
# [[12424   248]
#  [  922  1328]]
# AUC 0.7853257575757576
# acc: 91.25%
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     12672
#            1       0.84      0.58      0.68      2250
#
#    micro avg       0.92      0.92      0.92     14922
#    macro avg       0.88      0.78      0.82     14922
# weighted avg       0.91      0.92      0.91     14922
#
# [[12419   253]
#  [  955  1295]]
# AUC 0.7777951388888888

# %%
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# 91.42% (+/- 0.30%)

# %%
rus = RandomUnderSampler()
print("Before DownSampling, counts of label 1: %d" % (sum(y_train.values==1)))
print("Before DownSampling, counts of label 0: %d" % (sum(y_train.values==0)))
X_train_resample, y_train_resample = rus.fit_sample(X_train, y_train)
print("After DownSampling, counts of label '1': %s" % (sum(y_train_resample==1)))
print("After DownSampling, counts of label '0': %s" % (sum(y_train_resample==0)))
# Out:
# Before DownSampling, counts of label 1: 5452
# Before DownSampling, counts of label 0: 29365
# After DownSampling, counts of label '1': [5452]
# After DownSampling, counts of label '0': [5452]

# %%
# Undersampling with neural networks does not give better performance. The performance is actually slightly less, 
# when comparing the values for overall ROC, precision and recall of Bot.
